# %%
# !pip install git+https://github.com/davidteather/TikTok-Api
# !pip install google
# !python -m playwright install
# !apt install libgstreamer1.0-0 libwoff1 libgstreamer1.0-0 libgstreamer1.0-dev libgstreamer-plugins-good1.0-0 libgstreamer-gl1.0-0 libgstreamer-plugins-bad1.0-0
# Out:
# Collecting git+https://github.com/davidteather/TikTok-Api
#   Cloning https://github.com/davidteather/TikTok-Api to /tmp/pip-req-build-3xq5fjam
#   Running command git clone -q https://github.com/davidteather/TikTok-Api /tmp/pip-req-build-3xq5fjam
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from TikTokApi==3.9.9) (2.23.0)
# Collecting playwright
#   Downloading https://files.pythonhosted.org/packages/b7/50/d04a0ab3121906c575b8cf07baadfbd2436cc7dc8db74e62fe8549b88f60/playwright-1.12.1-py3-none-manylinux1_x86_64.whl (20.2MB)
#      |████████████████████████████████| 20.2MB 1.6MB/s
# Collecting selenium_stealth
#   Downloading https://files.pythonhosted.org/packages/cb/ac/7877df8b819d54a4e317a093a0a9e0a38d21d884a7250aa713f2f0869442/selenium_stealth-1.0.6-py3-none-any.whl
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 35.6MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->TikTokApi==3.9.9) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->TikTokApi==3.9.9) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->TikTokApi==3.9.9) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->TikTokApi==3.9.9) (1.24.3)
# Collecting pyee>=8.0.1
#   Downloading https://files.pythonhosted.org/packages/0d/0a/933b3931107e1da186963fd9bb9bceb9a613cff034cb0fb3b0c61003f357/pyee-8.1.0-py2.py3-none-any.whl
# Requirement already satisfied: greenlet>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from playwright->TikTokApi==3.9.9) (1.1.0)
# Requirement already satisfied: typing-extensions; python_version <= "3.8" in /usr/local/lib/python3.7/dist-packages (from playwright->TikTokApi==3.9.9) (3.7.4.3)
# Collecting websockets>=8.1
#   Downloading https://files.pythonhosted.org/packages/84/64/78c2b3fe37730b30dca3c93d1f7f4a4286767f86e7c04cf3571b39bc2fb7/websockets-9.1-cp37-cp37m-manylinux2010_x86_64.whl (103kB)
#      |████████████████████████████████| 112kB 54.5MB/s
# Building wheels for collected packages: TikTokApi
#   Building wheel for TikTokApi (setup.py) ... done
#   Created wheel for TikTokApi: filename=TikTokApi-3.9.9-cp37-none-any.whl size=55312 sha256=9b0d11b091f100a6252898482680d4c01d652ffa2f555c0a6436c2557c3eb405
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yamiyjvx/wheels/4c/7f/53/e4fc7bfa30b18c97537de52650a9cdf10c3a7cec7f53b1a1ea
# Successfully built TikTokApi
# Installing collected packages: pyee, websockets, playwright, selenium, selenium-stealth, TikTokApi
# Successfully installed TikTokApi-3.9.9 playwright-1.12.1 pyee-8.1.0 selenium-3.141.0 selenium-stealth-1.0.6 websockets-9.1
# Requirement already satisfied: google in /usr/local/lib/python3.7/dist-packages (2.0.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from google) (4.6.3)
# Downloading Playwright build of chromium v888113 - 124.3 Mb [] 0% 0.0s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 0% 8.9s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 0% 3.8s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 1% 2.8s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 2% 2.3s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 3% 2.1s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 4% 2.0s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 5% 1.9s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 6% 2.0s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 7% 1.9s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 8% 1.8s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 9% 1.7s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 10% 1.6s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 11% 1.6s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 13% 1.5s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 14% 1.5s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 15% 1.5s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 16% 1.4s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 16% 1.5s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 17% 1.5s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 18% 1.4s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 19% 1.4s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 21% 1.3s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 22% 1.3s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 24% 1.2s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 24% 1.3s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 25% 1.3s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 27% 1.3s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 28% 1.2s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 29% 1.2s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 31% 1.1s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 32% 1.1s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 34% 1.1s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 35% 1.0s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 37% 1.0s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 38% 1.0s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 39% 0.9s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 41% 0.9s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 42% 0.9s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 43% 0.9s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 45% 0.8s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 46% 0.8s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 48% 0.8s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 50% 0.7s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 51% 0.7s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 52% 0.7s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 53% 0.7s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 54% 0.7s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 55% 0.7s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 56% 0.6s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 58% 0.6s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 60% 0.6s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 61% 0.6s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 63% 0.5s Downloading Playwright build of chromium v888113 - 124.3 Mb [] 64% 0.5s Downloading Playwright build of chromium v888113 - 1 ...
# Playwright build of chromium v888113 downloaded to /root/.cache/ms-playwright/chromium-888113
# Downloading Playwright build of firefox v1271 - 72.9 Mb [] 0% 0.0s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 0% 7.5s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 0% 3.3s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 2% 1.8s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 3% 1.6s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 6% 1.2s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 8% 1.0s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 11% 0.8s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 14% 0.8s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 16% 0.7s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 18% 0.7s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 21% 0.7s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 23% 0.7s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 25% 0.6s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 26% 0.6s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 29% 0.6s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 31% 0.6s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 33% 0.5s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 36% 0.5s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 37% 0.5s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 40% 0.5s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 42% 0.5s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 45% 0.4s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 47% 0.4s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 50% 0.4s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 53% 0.4s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 56% 0.3s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 57% 0.3s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 59% 0.3s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 61% 0.3s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 64% 0.3s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 66% 0.3s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 67% 0.3s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 70% 0.2s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 73% 0.2s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 76% 0.2s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 77% 0.2s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 79% 0.2s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 81% 0.1s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 83% 0.1s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 85% 0.1s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 86% 0.1s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 88% 0.1s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 90% 0.1s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 91% 0.1s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 93% 0.1s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 95% 0.0s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 99% 0.0s Downloading Playwright build of firefox v1271 - 72.9 Mb [] 100% 0.0s
# Playwright build of firefox v1271 downloaded to /root/.cache/ms-playwright/firefox-1271
# Downloading Playwright build of webkit v1492 - 72.3 Mb [] 0% 0.0s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 0% 7.4s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 0% 3.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 1% 2.8s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 2% 2.4s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 3% 2.2s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 5% 2.1s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 6% 2.1s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 7% 2.1s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 8% 2.1s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 9% 2.0s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 10% 1.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 11% 1.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 12% 1.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 13% 1.8s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 14% 1.8s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 15% 1.8s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 16% 1.7s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 17% 1.7s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 18% 1.7s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 19% 1.7s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 20% 1.6s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 21% 1.6s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 22% 1.6s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 23% 1.5s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 24% 1.5s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 25% 1.5s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 26% 1.5s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 27% 1.4s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 28% 1.4s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 29% 1.4s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 30% 1.4s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 31% 1.3s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 32% 1.3s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 33% 1.3s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 34% 1.3s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 35% 1.3s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 37% 1.2s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 38% 1.2s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 39% 1.2s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 40% 1.2s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 41% 1.2s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 42% 1.2s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 43% 1.2s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 44% 1.1s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 45% 1.1s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 46% 1.1s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 47% 1.1s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 48% 1.0s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 49% 1.0s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 50% 1.0s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 51% 1.0s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 52% 1.0s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 53% 0.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 54% 0.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 55% 0.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 56% 0.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 57% 0.9s Downloading Playwright build of webkit v1492 - 72.3 Mb [] 58% 0.8s Downloading Playwright build of webkit v1492 - 72.3 Mb []  ...
# Playwright build of webkit v1492 downloaded to /root/.cache/ms-playwright/webkit-1492
# Downloading Playwright build of ffmpeg v1005 - 2.6 Mb [] 0% 0.0s Downloading Playwright build of ffmpeg v1005 - 2.6 Mb [] 5% 0.3s Downloading Playwright build of ffmpeg v1005 - 2.6 Mb [] 31% 0.1s Downloading Playwright build of ffmpeg v1005 - 2.6 Mb [] 65% 0.0s Downloading Playwright build of ffmpeg v1005 - 2.6 Mb [] 100% 0.0s
# Playwright build of ffmpeg v1005 downloaded to /root/.cache/ms-playwright/ffmpeg-1005
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-gstreamer-1.0
#   gstreamer1.0-gl gstreamer1.0-plugins-base intltool-debian
#   libarchive-cpio-perl libarchive-zip-perl libbrotli1 libcap2-bin
#   libcdparanoia0 libfile-stripnondeterminism-perl libgraphene-1.0-0
#   libgstreamer-plugins-base1.0-0 libmagic-mgc libmagic1 libmail-sendmail-perl
#   liborc-0.4-0 libpam-cap libsigsegv2 libsys-hostname-long-perl
#   libtimedate-perl libtool libvisual-0.4-0 m4 po-debconf
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev gvfs libvisual-0.4-plugins
#   gstreamer1.0-tools gstreamer1.0-doc libtool-doc gcj-jdk m4-doc
#   libmail-box-perl
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-gstreamer-1.0
#   gstreamer1.0-gl gstreamer1.0-plugins-base intltool-debian
#   libarchive-cpio-perl libarchive-zip-perl libbrotli1 libcap2-bin
#   libcdparanoia0 libfile-stripnondeterminism-perl libgraphene-1.0-0
#   libgstreamer-gl1.0-0 libgstreamer-plugins-bad1.0-0
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgstreamer1.0-dev libmagic-mgc libmagic1
#   libmail-sendmail-perl liborc-0.4-0 libpam-cap libsigsegv2
#   libsys-hostname-long-perl libtimedate-perl libtool libvisual-0.4-0 libwoff1
#   m4 po-debconf
# 0 upgraded, 40 newly installed, 0 to remove and 39 not upgraded.
# Need to get 8,620 kB of archives.
# After this operation, 40.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcap2-bin amd64 1:2.25-1.2 [20.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpam-cap amd64 1:2.25-1.2 [7,268 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer1.0-0 amd64 1.14.5-0ubuntu1~18.04.2 [865 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-gstreamer-1.0 amd64 1.14.5-0ubuntu1~18.04.2 [71.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphene-1.0-0 amd64 1.8.0-1 [37.4 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 liborc-0.4-0 amd64 1:0.4.28-1 [137 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.14.5-0ubuntu1~18.04.3 [689 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.14.5-0ubuntu1~18.04.3 [147 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-gl amd64 1.14.5-0ubuntu1~18.04.3 [84.0 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvisual-0.4-0 amd64 0.4.0-11 [99.2 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-plugins-base amd64 1.14.5-0ubuntu1~18.04.3 [586 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbrotli1 amd64 1.0.3-1ubuntu1.3 [262 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer1.0-dev amd64 1.14.5-0ubuntu1~18.04.2 [398 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwoff1 amd64 1.0.2-1build0.1 [43.0 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libgstreamer-plugins-bad1.0-0 amd64 1.14.5-0ubuntu1~18.04.1 [322 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.14.5-0ubuntu1~18.04.2 [62.6 kB]
# Fetched 8,620 kB in 1s (7,268 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libcap2-bin.
# Preparing to unpack .../03-libcap2-bin_1%3a2.25-1.2_amd64.deb ...
# Unpacking libcap2-bin (1:2.25-1.2) ...
# Selecting previously unselected package libpam-cap:amd64.
# Preparing to unpack .../04-libpam-cap_1%3a2.25-1.2_amd64.deb ...
# Unpacking libpam-cap:amd64 (1:2.25-1.2) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../05-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../06-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../07-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../08-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../09-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../10-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../11-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../12-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../13-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../14-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../15-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../16-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../17-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../18-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../19-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../20-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../21-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package libgstreamer1.0-0:amd64.
# Preparing to unpack .../22-libgstreamer1.0-0_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package gir1.2-gstreamer-1.0:amd64.
# Preparing to unpack .../23-gir1.2-gstreamer-1.0_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking gir1.2-gstreamer-1.0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../24-libgraphene-1.0-0_1.8.0-1_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.8.0-1) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../25-liborc-0.4-0_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../26-libgstreamer-plugins-base1.0-0_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../27-libgstreamer-gl1.0-0_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../28-gstreamer1.0-gl_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../29-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../30-libvisual-0.4-0_0.4.0-11_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-11) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../31-gstreamer1.0-plugins-base_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../32-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libbrotli1:amd64.
# Preparing to unpack .../33-libbrotli1_1.0.3-1ubuntu1.3_amd64.deb ...
# Unpacking libbrotli1:amd64 (1.0.3-1ubuntu1.3) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../34-libgstreamer1.0-dev_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Adding 'diversion of /usr/bin/dh_gstscancodecs to /usr/bin/dh_gstscancodecs-gst0.10 by libgstreamer1.0-dev'
# Adding 'diversion of /usr/share/man/man1/dh_gstscancodecs.1.gz to /usr/share/man/man1/dh_gstscancodecs.1.gz-gst0.10 by libgstreamer1.0-dev'
# Unpacking libgstreamer1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../35-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../36-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../37-libwoff1_1.0.2-1build0.1_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build0.1) ...
# Selecting previously unselected package libgstreamer-plugins-bad1.0-0:amd64.
# Preparing to unpack .../38-libgstreamer-plugins-bad1.0-0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer-plugins-bad1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../39-libgstreamer-plugins-good1.0-0_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up libbrotli1:amd64 (1.0.3-1ubuntu1.3) ...
# Setting up libpam-cap:amd64 (1:2.25-1.2) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libwoff1:amd64 (1.0.2-1build0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up libcap2-bin (1:2.25-1.2) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-11) ...
# Setting up libgraphene-1.0-0:amd64 (1.8.0-1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up gir1.2-gstreamer-1.0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up gstreamer1.0-gl:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up libgstreamer-plugins-bad1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up libgstreamer1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-autoreconf (17) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !pip install flatten-dict
# Out:
# Collecting flatten-dict
#   Downloading https://files.pythonhosted.org/packages/ab/51/4e2cb420b4b544676d1806ff7c5a1121b793d6a1aec844d3ddc83f3f8069/flatten_dict-0.4.0-py2.py3-none-any.whl
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from flatten-dict) (1.15.0)
# Installing collected packages: flatten-dict
# Successfully installed flatten-dict-0.4.0

# %%
# %%writefile test.py
from TikTokApi import TikTokApi
import pandas as pd

from flatten_dict import flatten
api = TikTokApi.get_instance()
n_videos = 10000
'''
hashtag_list = ['JusticeforJenifer', 'JusticeforUwa', 'MeToo', 'ArewaMeTo', 'gb', 'genderbasedviolence', 'domesticviolence', 
'endgbv', 'GBVNigeria', 'metoo', 'guidedbyvoices', 'stopgbv', 'consent', 'domesticabuse', 'arewametoo', 'sexualabuse', 
'sexualexploitation', 'sexualharassment', 'violenceagainstwomen', 'rape', 'sexualassault', 'humanrightsviolation', 'SpotlightEndViolence', 'SpotlightNG']
'''
hashtag_list = ['justiceforuwa', 'justiceforjennifer', 'metoo', 'gbv', 'genderbasedviolence', 'endgbv']

res = pd.DataFrame()
for hashtag in hashtag_list:
	hashtag_videos = api.byHashtag(hashtag, count = n_videos)
	print(len(hashtag_videos))

	current_res = pd.DataFrame()
	for video in hashtag_videos:
		video = flatten(video, reducer = 'path')
		video_id, author = video['id'], video['author/uniqueId']
		df = pd.DataFrame([video])
		df['hashtag'] = hashtag
		df['video/url'] = 'https://www.tiktok.com/@' + str(author) + '/video/' + str(video_id)
		current_res = current_res.append(df)

	print(hashtag, current_res.shape)
	res = res.append(current_res)
print(res.shape)
res.to_excel("tiktok_video_by_hashtag_1.xlsx", index = False)
# Out:
# Overwriting test.py

# %%
# !sudo apt-get install libnotify4\
          libenchant1c2a\
          libsecret-1-0\
          libhyphen0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aspell aspell-en dictionaries-common emacsen-common enchant hunspell-en-us
#   libaspell15 libhunspell-1.6-0 libsecret-common libtext-iconv-perl
#   notification-daemon
# Suggested packages:
#   aspell-doc spellutils wordlist hunspell openoffice.org-hunspell
#   | openoffice.org-core libenchant-voikko
# The following NEW packages will be installed:
#   aspell aspell-en dictionaries-common emacsen-common enchant hunspell-en-us
#   libaspell15 libenchant1c2a libhunspell-1.6-0 libhyphen0 libnotify4
#   libsecret-1-0 libsecret-common libtext-iconv-perl notification-daemon
# 0 upgraded, 15 newly installed, 0 to remove and 39 not upgraded.
# Need to get 1,490 kB of archives.
# After this operation, 6,067 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtext-iconv-perl amd64 1.7-5build6 [13.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaspell15 amd64 0.60.7~20110707-4ubuntu0.1 [309 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 emacsen-common all 2.0.8 [17.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 dictionaries-common all 1.27.2 [186 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 aspell amd64 0.60.7~20110707-4ubuntu0.1 [87.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 aspell-en all 2017.08.24-0-0.1 [298 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 hunspell-en-us all 1:2017.08.24 [168 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhunspell-1.6-0 amd64 1.6.2-1 [154 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libenchant1c2a amd64 1.6.0-11.1 [64.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 enchant amd64 1.6.0-11.1 [12.2 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhyphen0 amd64 2.8.8-5 [26.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnotify4 amd64 0.7.7-3 [17.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsecret-common all 0.18.6-1 [4,452 B]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsecret-1-0 amd64 0.18.6-1 [94.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 notification-daemon amd64 3.20.0-3 [36.9 kB]
# Fetched 1,490 kB in 1s (2,119 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 15.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libtext-iconv-perl.
# (Reading database ... 162504 files and directories currently installed.)
# Preparing to unpack .../00-libtext-iconv-perl_1.7-5build6_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-5build6) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../01-libaspell15_0.60.7~20110707-4ubuntu0.1_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.7~20110707-4ubuntu0.1) ...
# Selecting previously unselected package emacsen-common.
# Preparing to unpack .../02-emacsen-common_2.0.8_all.deb ...
# Unpacking emacsen-common (2.0.8) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../03-dictionaries-common_1.27.2_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.27.2) ...
# Selecting previously unselected package aspell.
# Preparing to unpack .../04-aspell_0.60.7~20110707-4ubuntu0.1_amd64.deb ...
# Unpacking aspell (0.60.7~20110707-4ubuntu0.1) ...
# Selecting previously unselected package aspell-en.
# Preparing to unpack .../05-aspell-en_2017.08.24-0-0.1_all.deb ...
# Unpacking aspell-en (2017.08.24-0-0.1) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../06-hunspell-en-us_1%3a2017.08.24_all.deb ...
# Unpacking hunspell-en-us (1:2017.08.24) ...
# Selecting previously unselected package libhunspell-1.6-0:amd64.
# Preparing to unpack .../07-libhunspell-1.6-0_1.6.2-1_amd64.deb ...
# Unpacking libhunspell-1.6-0:amd64 (1.6.2-1) ...
# Selecting previously unselected package libenchant1c2a:amd64.
# Preparing to unpack .../08-libenchant1c2a_1.6.0-11.1_amd64.deb ...
# Unpacking libenchant1c2a:amd64 (1.6.0-11.1) ...
# Selecting previously unselected package enchant.
# Preparing to unpack .../09-enchant_1.6.0-11.1_amd64.deb ...
# Unpacking enchant (1.6.0-11.1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../10-libhyphen0_2.8.8-5_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-5) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../11-libnotify4_0.7.7-3_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.7-3) ...
# Selecting previously unselected package libsecret-common.
# Preparing to unpack .../12-libsecret-common_0.18.6-1_all.deb ...
# Unpacking libsecret-common (0.18.6-1) ...
# Selecting previously unselected package libsecret-1-0:amd64.
# Preparing to unpack .../13-libsecret-1-0_0.18.6-1_amd64.deb ...
# Unpacking libsecret-1-0:amd64 (0.18.6-1) ...
# Selecting previously unselected package notification-daemon.
# Preparing to unpack .../14-notification-daemon_3.20.0-3_amd64.deb ...
# Unpacking notification-daemon (3.20.0-3) ...
# Setting up libnotify4:amd64 (0.7.7-3) ...
# Setting up libsecret-common (0.18.6-1) ...
# Setting up libhunspell-1.6-0:amd64 (1.6.2-1) ...
# Setting up libaspell15:amd64 (0.60.7~20110707-4ubuntu0.1) ...
# Setting up emacsen-common (2.0.8) ...
# Setting up libhyphen0:amd64 (2.8.8-5) ...
# Setting up libtext-iconv-perl (1.7-5build6) ...
# Setting up libsecret-1-0:amd64 (0.18.6-1) ...
# Setting up notification-daemon (3.20.0-3) ...
# Setting up dictionaries-common (1.27.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up aspell (0.60.7~20110707-4ubuntu0.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up hunspell-en-us (1:2017.08.24) ...
# Setting up libenchant1c2a:amd64 (1.6.0-11.1) ...
# Setting up aspell-en (2017.08.24-0-0.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up enchant (1.6.0-11.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dictionaries-common (1.27.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# aspell-autobuildhash: processing: en [en-common].
# aspell-autobuildhash: processing: en [en-variant_0].
# aspell-autobuildhash: processing: en [en-variant_1].
# aspell-autobuildhash: processing: en [en-variant_2].
# aspell-autobuildhash: processing: en [en-w_accents-only].
# aspell-autobuildhash: processing: en [en-wo_accents-only].
# aspell-autobuildhash: processing: en [en_AU-variant_0].
# aspell-autobuildhash: processing: en [en_AU-variant_1].
# aspell-autobuildhash: processing: en [en_AU-w_accents-only].
# aspell-autobuildhash: processing: en [en_AU-wo_accents-only].
# aspell-autobuildhash: processing: en [en_CA-variant_0].
# aspell-autobuildhash: processing: en [en_CA-variant_1].
# aspell-autobuildhash: processing: en [en_CA-w_accents-only].
# aspell-autobuildhash: processing: en [en_CA-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-variant_0].
# aspell-autobuildhash: processing: en [en_GB-variant_1].
# aspell-autobuildhash: processing: en [en_US-w_accents-only].
# aspell-autobuildhash: processing: en [en_US-wo_accents-only].

# %%
# !python test.py
# Out:
# ERROR:root:Tiktok wants to display a catcha. Response is:
# {"code":"10000","from":"","type":"verify","version":"","region":"va","subtype":"slide","detail":"mUmpsX0S6P239AuQKA*Kq2FQEafhQUJeq8thN3j0YonK*pri5oElL8DY8aIEyy*A4JvsujkP4yv9sDCjhY6MFXnxPD*0wF1k5XJl-ox3nzLQrniTJnhvgt8XjMrNv-nkeA0wrhf-4fKTtWD-sas9jrkMznd*Dt0RouSH-djMdGPfUVvPrs0XrcWwHt8HyRgl8DbE49y2MM7PMAaOEQhBut1mIb9qnq94nBa*45I1sr8LU8GZeuL8G9WATOE7iN8f2qxpeXJ*M*uFu5cHd3seaI*z936LfazXDh5FCWnbJzSkPUdasst5Wbwel5YXG9CZg4SAsjitJMEy0i2mYEn4KBBfd19NJjbsd0K6Tu*LTOCj5QDrc*-fhUc5bJeQI1d413zf6lFeKfxyr63b8xByrSlFTPd-DrT*pG9syhuZiw..","verify_event":"","fp":"verify_khr3jabg_V7ucdslq_Vrw9_4KPb_AJ1b_Ks706M8zIJTq","scene":"","verify_ticket":"","channel_mobile":"","sms_content":"","mobile":"","email":""}
# ERROR:root:{'tt_webid': '5155334179136349143', 'tt_webid_v2': '5155334179136349143', 'csrf_session_id': 'a67c3bdb40cb45f7b25532f4cbae098a', 'tt_csrf_token': 'gQUKkTowlmiDMkxe'}
# Traceback (most recent call last):
#   File "test.py", line 16, in <module>
#     hashtag_videos = api.byHashtag(hashtag, count = n_videos)
#   File "/usr/local/lib/python3.7/dist-packages/TikTokApi/tiktok.py", line 958, in by_hashtag
#     res = self.get_data(url=api_url, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/TikTokApi/tiktok.py", line 287, in get_data
#     raise TikTokCaptchaError()
# TikTokApi.exceptions.TikTokCaptchaError: TikTok blocks this request displaying a Captcha
# Tip: Consider using a proxy or a custom_verifyFp as method parameters
